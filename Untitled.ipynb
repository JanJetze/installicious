# %%
import feather
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
from pprint import pprint
import scipy as sp

FILE_PATH = 'data_science_case/'

# %%
anp_df = feather.read_dataframe(FILE_PATH + 'anp.feather')
face_df = feather.read_dataframe(FILE_PATH + 'face.feather')
image_df = feather.read_dataframe(FILE_PATH + 'image_data.feather')
metrics_df = feather.read_dataframe(FILE_PATH + 'image_metrics.feather')
object_labels_df = feather.read_dataframe(FILE_PATH + 'object_labels.feather')
survey_df = feather.read_dataframe(FILE_PATH + 'survey.feather')

# %%
# Merge them based on the image_id so that we have a large data frame containing all the elements

image_anp_frame = pd.merge(image_df, anp_df, how='inner', on='image_id')
im_anp_obj_frame = pd.merge(image_anp_frame, object_labels_df, how='inner', on='image_id')
im_anp_obj_face_frame = pd.merge(im_anp_obj_frame, face_df, how='inner', on='image_id')

# %%
image_frame = im_anp_obj_face_frame.drop_duplicates().reset_index()

# %%
image_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2464794 entries, 0 to 2464793
# Data columns (total 41 columns):
# index                        int64
# image_id                     object
# image_link                   object
# image_url                    object
# image_height                 float64
# image_width                  float64
# image_filter                 object
# image_posted_time_unix       object
# image_posted_time            object
# data_memorability            float64
# user_id                      object
# user_full_name               object
# user_name                    object
# user_website                 object
# user_profile_pic             object
# user_bio                     object
# user_followed_by             float64
# user_follows                 float64
# user_posted_photos           float64
# anp_label                    object
# anp_sentiment                float64
# emotion_score                float64
# emotion_label                object
# ...

# %%
correlation_matrix = image_frame.corr()

# %%
correlation_matrix
# Out:
#                               index  image_height  image_width  \
# index                      1.000000     -0.011954     0.035112
# image_height              -0.011954      1.000000     0.355172
# image_width                0.035112      0.355172     1.000000
# data_memorability          0.025624      0.108650    -0.046510
# user_followed_by           0.370505     -0.056107     0.014521
# user_follows               0.113293     -0.120055    -0.057412
# user_posted_photos        -0.021638      0.065066     0.065928
# anp_sentiment             -0.009438      0.019035    -0.007790
# emotion_score              0.002862      0.004138    -0.004366
# data_amz_label_confidence  0.012376      0.018421    -0.001136
# face_id                   -0.071935     -0.039918     0.030873
# face_gender_confidence     0.005197     -0.007972    -0.006358
# face_age_range_high        0.050150     -0.061223    -0.014937
# face_age_range_low         0.035148     -0.062671    -0.014108
# ...

# %%
import seaborn as sns
# %matplotlib inline

# %%
plt.imshow(correlation_matrix, cmap='gray')
plt.show()

# %%
spear = sp.stats.spearmanr(correlation_matrix)

# %%
spear[0]
# Out:
# array([[ 1.        , -0.41652174, -0.00521739, -0.30956522,  0.78782609,
#          0.30869565,  0.40521739, -0.36956522, -0.3626087 , -0.0026087 ,
#         -0.0826087 ,  0.09304348,  0.50347826,  0.47913043,  0.2773913 ,
#          0.55130435, -0.63304348,  0.56608696, -0.60782609, -0.54521739,
#         -0.64347826,  0.30434783, -0.39913043, -0.70782609],
#        [-0.41652174,  1.        ,  0.24347826,  0.63217391, -0.53391304,
#         -0.81217391, -0.39913043,  0.59217391,  0.43217391,  0.6026087 ,
#         -0.32956522, -0.24956522, -0.7026087 , -0.68869565, -0.44608696,
#         -0.54782609,  0.55913043, -0.51913043,  0.56      ,  0.40521739,
#          0.45391304, -0.44086957,  0.57043478,  0.21217391],
#        [-0.00521739,  0.24347826,  1.        , -0.1973913 ,  0.17304348,
#         -0.16086957,  0.4026087 , -0.26695652, -0.43565217,  0.06521739,
#          0.23652174, -0.62869565,  0.13826087,  0.15652174,  0.32434783,
# ...

# %%
image_test = image_frame[-1000:]
image_train = image_frame[:-1000]

# %%
regr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-011f07b66b12> in <module>()
# ----> 1 regr
#
# NameError: name 'regr' is not defined

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 45 columns):
# id                 332 non-null object
# gender             332 non-null object
# born               332 non-null int32
# education          332 non-null object
# employed           332 non-null object
# income             332 non-null object
# A_2                332 non-null int32
# N_1                332 non-null int32
# P_1                332 non-null int32
# E_1                332 non-null int32
# A_1                332 non-null int32
# H_1                332 non-null int32
# M_1                332 non-null int32
# R_1                332 non-null int32
# M_2                332 non-null int32
# E_2                332 non-null int32
# LON                332 non-null int32
# H_2                332 non-null int32
# P_2                332 non-null int32
# N_2                332 non-null int32
# A_3                332 non-null int32
# N_3                332 non-null int32
# ...

# %%
survey_df['PERMA'].head(15)
# Out:
# 0      5
# 1      9
# 2      6
# 3      1
# 4      8
# 5      7
# 6      7
# 7      2
# 8      8
# 9      9
# 10    10
# 11     8
# 12     1
# 13     7
# 14     7
# Name: PERMA, dtype: int32

# %%
image_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2464794 entries, 0 to 2464793
# Data columns (total 41 columns):
# index                        int64
# image_id                     object
# image_link                   object
# image_url                    object
# image_height                 float64
# image_width                  float64
# image_filter                 object
# image_posted_time_unix       object
# image_posted_time            object
# data_memorability            float64
# user_id                      object
# user_full_name               object
# user_name                    object
# user_website                 object
# user_profile_pic             object
# user_bio                     object
# user_followed_by             float64
# user_follows                 float64
# user_posted_photos           float64
# anp_label                    object
# anp_sentiment                float64
# emotion_score                float64
# emotion_label                object
# ...

# %%
image_frame['anp_label'].value_counts()
# Out:
# silly_faces               45618
# comic_life                29844
# cute_couple               19212
# old_friends               18930
# happy_couple              15648
# true_story                15642
# ugly_sweater              15255
# great_day                 13770
# happy_birthday            13461
# lovely_ladies             12831
# cute_baby                 12807
# bad_hair                  12231
# early_days                12066
# happy_baby                11703
# hot_guys                  11226
# late_dinner               11226
# funny_quotes              11154
# great_grandmother         10602
# good_friends              10464
# plastic_surgery           10209
# double_portrait           10179
# big_glasses               10176
# fake_vintage              10023
# good_day                   9801
# formal_night               9399
# modern_family              9345
# happy_days                 9345
# happy_people               9267
# cute_guy                   9072
# ...

# %%
len(image_frame['user_id'].unique())
# Out:
# 144

# %%
image_frame.head()
# Out:
#    index                      image_id  \
# 0      0  552382455733335946_263042348
# 1      1  552382455733335946_263042348
# 2      2  552382455733335946_263042348
# 3      3  552382455733335946_263042348
# 4      4  552382455733335946_263042348
#
#                                 image_link  \
# 0  https://www.instagram.com/p/eqdOq2JLeK/
# 1  https://www.instagram.com/p/eqdOq2JLeK/
# 2  https://www.instagram.com/p/eqdOq2JLeK/
# 3  https://www.instagram.com/p/eqdOq2JLeK/
# 4  https://www.instagram.com/p/eqdOq2JLeK/
#
#                                            image_url  image_height  \
# 0  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 1  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 2  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 3  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 4  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
#
# ...

# %%
image_frame[:100000].to_csv('image_frame.csv', sep=';', encoding='utf-8')

# %%
survey_df.to_csv('survey_frame.csv', sep=';', encoding='utf-8')
